# %%
# initialize
from datamart_isi.entries import Datamart
from d3m.container.dataset import Dataset, D3MDatasetLoader
from common_primitives.denormalize import Hyperparams as hyper_denormalize, DenormalizePrimitive
from d3m.base import utils as d3m_utils
import os
import pandas as pd

# %%
# load the ISI datamart, currently the url is here, may change in the future
isi_datamart_url = "http://dsbox02.isi.edu:9001/blazegraph/namespace/datamart3/sparql"
a = Datamart(connection_url=isi_datamart_url)
# load the D3M dataset,here we use "DA_poverty_estimation" as exmaple ,please change to your dataset path
loader = D3MDatasetLoader()
path = "/Users/minazuki/Desktop/studies/master/2018Summer/data/datasets/seed_datasets_data_augmentation/DA_poverty_estimation/TRAIN/dataset_TRAIN/datasetDoc.json"
json_file = os.path.abspath(path)
all_dataset_uri = 'file://{}'.format(json_file)
all_dataset = loader.load(dataset_uri=all_dataset_uri)
# run denormlaize primitive
denormalize_hyperparams = hyper_denormalize.defaults()
denormalize_primitive = DenormalizePrimitive(hyperparams = denormalize_hyperparams)
all_dataset = denormalize_primitive.produce(inputs = all_dataset).value

# %%
all_dataset['learningData'].head()
# Out:
#   d3mIndex   FIPS State              Area RUCCode POVALL_2016
# 0        1  13297    GA     Walton County       1       11385
# 1        2  13137    GA  Habersham County       6        6500
# 2        3  54017    WV  Doddridge County       9        1460
# 3        4  55055    WI  Jefferson County       4        7618
# 4        5  38065    ND     Oliver County       8         191

# %%
"""
start search, run search with data function.
Here because the dataset do not have any "Text" semantic type columns,
the system will said that no columns can be augment
"""
search_res = a.search_with_data(query=None, supplied_data=all_dataset)
# Out:
# No columns can be augment with datamart!
# [INFO] No Q nodes columns found in input data, will run wikifier.

# %%
"""
run get next page, we will get real search results, it will only have 2 wikidata search results
Explain:
here we do not find any "Qnodes" semantic type columns, so we will try to run wikifier before searching in wikidata database
Then, We will generate 2 Q nodes columns for FIPS and State. 
These 2 columns can be used to search in wikidata database
Because searching on wikidata with large amount of Q nodes, it will take about 3 minutes or more to finish
"""
s1 = search_res.get_next_page()
# Out:
# d3m.primitives.data_cleaning.cleaning_featurizer.DSBOX: Primitive is not providing a description through its docstring.
# d3m.primitives.data_cleaning.column_fold.DSBOX: Primitive is not providing a description through its docstring.
# warn from part 4 d3m.primitives.data_cleaning.labeler.DSBOX
# {1, 2, 3, 4}
# Current column: FIPS
# The best matching P node is P882
# Current column: State
# The best matching P node is P5086
# Current column: Area
# [ERROR] No candidate P nodes found for input column : [Area]
# Current column: RUCCode
# A columns with all numerical values and useless detected, skipped
# Wikidata Q nodes inputs detected! Will search with it.
# Totally 2 Q nodes columns detected!

# %%
# because no more serach results found, s2 will be None
s2 = search_res.get_next_page()

# %%
# show the search results details
# wikidata has no dynamic score
output_df = pd.DataFrame()
for each in s1:
    col1 = each.display()
    output_df = output_df.append(col1)
output_df
# Out:
#                                        title  \
# 0   wikidata search result for FIPS_wikidata
# 0  wikidata search result for State_wikidata
#
#                                              columns    join columns  score
# 0                        population, area, inception   FIPS_wikidata      1
# 0  population, nickname, motto text, demonym, nat...  State_wikidata      1

# %%
# augment with these 2 wikidata search results
aug1 = s1[0].augment(supplied_data=search_res.supplied_data)
aug2 = s1[1].augment(supplied_data=aug1)

# %%
search_res.supplied_data['learningData'].shape
# Out:
# (2038, 8)

# %%
# reutrned aug2 is a d3m.container.dataset
res_id, aug2_dataframe = d3m_utils.get_tabular_resource(dataset=aug2, resource_id=None)
aug2_dataframe.head()
# Out:
#   d3mIndex   FIPS State               Area RUCCode POVALL_2016 FIPS_wikidata  \
# 0     1201  13003    GA    Atkinson County       9        2176       Q488194
# 1     2649  13233    GA        Polk County       6        7609       Q498395
# 2      939  13199    GA  Meriwether County       1        4417       Q501151
# 3     2862  13143    GA    Haralson County       1        5306       Q544539
# 4     1526  13207    GA      Monroe County       3        3197       Q493024
#
#   State_wikidata area_for_FIPS_wikidata population_for_FIPS_wikidata  \
# 0          Q1428                    891                         8290
# 1          Q1428                    808                        41183
# 2          Q1428                   1309                        21232
# 3          Q1428                    733                        28495
# 4          Q1428                   1030                        26984
#
#   area_for_State_wikidata elevation above sea level_for_State_wikidata  \
# 0                  153909                                          180
# 1                  153909                                          180
# 2                  153909                                          180
# 3                  153909                                          180
# 4                  153909                                          180
#
#   inception_for_State_wikidata motto text_for_State_wikidata  \
# 0         1788-01-02T00:00:00Z   Wisdom, Justice, Moderation
# 1         1788-01-02T00:00:00Z   Wisdom, Justice, Moderation
# 2         1788-01-02T00:00:00Z   Wisdom, Justice, Moderation
# 3         1788-01-02T00:00:00Z   Wisdom, Justice, Moderation
# 4         1788-01-02T00:00:00Z   Wisdom, Justice, Moderation
#
#   native label_for_State_wikidata nickname_for_State_wikidata  \
# 0                State of Georgia                         nan
# 1                State of Georgia                         nan
# 2                State of Georgia                         nan
# 3                State of Georgia                         nan
# 4                State of Georgia                         nan
#
#   population_for_State_wikidata short name_for_State_wikidata  \
# 0                      10214860                            GA
# 1                      10214860                            GA
# 2                      10214860                            GA
# 3                      10214860                            GA
# 4                      10214860                            GA
#
#   water as percent of area_for_State_wikidata
# 0                                        3.22
# 1                                        3.22
# 2                                        3.22
# 3                                        3.22
# 4                                        3.22

# %%
aug2_dataframe
# Out:
#      d3mIndex   FIPS State                  Area RUCCode POVALL_2016  \
# 0        1201  13003    GA       Atkinson County       9        2176
# 1        2649  13233    GA           Polk County       6        7609
# 2         939  13199    GA     Meriwether County       1        4417
# 3        2862  13143    GA       Haralson County       1        5306
# 4        1526  13207    GA         Monroe County       3        3197
# 5        2303  13313    GA      Whitfield County       3       16688
# 6        2547  13261    GA         Sumter County       6        8290
# 7         701  13053    GA  Chattahoochee County       2        1639
# 8          82  13195    GA        Madison County       3        4255
# 9          60  13105    GA         Elbert County       6        4197
# 10       1319  13127    GA          Glynn County       3       15916
# 11       1046  13257    GA       Stephens County       7        5212
# 12       2247  13303    GA     Washington County       7        5063
# 13       1929  13147    GA           Hart County       6        4286
# 14        148  13061    GA           Clay County       9        1040
# 15       2492  13179    GA        Liberty County       3        9184
# 16       2172  13193    GA          Macon County       6        3701
# 17        310  13071    GA       Colquitt County       6       11252
# 18       3128  13171    GA          Lamar County       1        3142
# 19       1968  13227    GA        Pickens County       1        3447
# 20       2328  13185    GA        Lowndes County       3       23936
# 21       3111  13157    GA        Jackson County       6        8097
# 22       2411  13013    GA         Barrow County       1        9888
# 23       1205  13091    GA          Dodge County       7        4730
# 24       2039  13175    GA        Laurens County       6       11931
# 25       1349  13269    GA         Taylor County       8        2004
# 26        273  13125    GA       Glascock County       9         539
# 27         46  13067    GA           Cobb County       1       73446
# 28       2820  13177    GA            Lee County       3        3190
# 29       3106  13187    GA        Lumpkin County       6        4711
# ...       ...    ...   ...                   ...     ...         ...
# 2008     2391  15001    HI         Hawaii County       5       29962
# 2009      851  15003    HI       Honolulu County       2       81341
# 2010      563  10005    DE         Sussex County       4       25212
# 2011     2056  10003    DE     New Castle County       1       61319
# 2012     1325  10001    DE           Kent County       3       23060
# 2013     1460  23031    ME           York County       2       16132
# 2014     1781  23009    ME        Hancock County       6        5877
# 2015     1947  23011    ME       Kennebec County       4       16479
# 2016      570  23017    ME         Oxford County       6        7565
# 2017     2973  23025    ME       Somerset County       6        9749
# 2018      909  23015    ME        Lincoln County       8        3818
# 2019     3112  23027    ME          Waldo County       6        5514
# 2020      934  23007    ME       Franklin County       6        4111
# 2021     1782  23023    ME      Sagadahoc County       2        3245
# 2022      735   4025    AZ        Yavapai County       3       29418
# 2023     1377   4027    AZ           Yuma County       3       37850
# 2024     2364   4003    AZ        Cochise County       4       25424
# 2025     1849   4019    AZ           Pima County       2      180513
# 2026     1895   4012    AZ         La Paz County       6        4976
# 2027      724   4011    AZ       Greenlee County       7        1144
# 2028      914   4017    AZ         Navajo County       4       30379
# 2029     1589   4001    AZ         Apache County       6       23966
# 2030     1129   9001    CT      Fairfield County       2       79966
# 2031     1332   9011    CT     New London County       2       23961
# 2032     1235   9003    CT       Hartford County       1       95010
# 2033     1329   9007    CT      Middlesex County       1       12513
# 2034     1752   9015    CT        Windham County       4       13297
# 2035     1784  44005    RI        Newport County       1        7120
# 2036     1858  44009    RI     Washington County       1       11789
# 2037     2171  44003    RI           Kent County       1       15726
#
#      FIPS_wikidata State_wikidata area_for_FIPS_wikidata  \
# 0          Q488194          Q1428                    891
# 1          Q498395          Q1428                    808
# 2          Q501151          Q1428                   1309
# 3          Q544539          Q1428                    733
# 4          Q493024          Q1428                   1030
# 5          Q491537          Q1428                  751.1
# 6          Q503076          Q1428                   1276
# 7          Q486394          Q1428                    651
# 8          Q156387          Q1428                    740
# 9          Q492016          Q1428                    970
# 10         Q487016          Q1428                   1516
# 11         Q498362          Q1428                    477
# 12         Q498286          Q1428                    nan
# 13         Q491301          Q1428                    664
# 14         Q156580          Q1428                    562
# 15         Q487692          Q1428                   1561
# 16         Q492021          Q1428                   1051
# 17         Q113005          Q1428                   1441
# 18         Q493049          Q1428                    481
# 19         Q498675          Q1428                    603
# 20         Q493134          Q1428                   1323
# 21         Q486137          Q1428                    888
# 22         Q486838          Q1428                    422
# 23         Q115272          Q1428                   1303
# 24         Q491556          Q1428                   2120
# 25         Q505299          Q1428                    983
# 26         Q477951          Q1428                    374
# 27         Q484247          Q1428                    881
# 28         Q491508          Q1428                    938
# 29         Q492040          Q1428                    738
# ...            ...            ...                    ...
# 2008       Q487334           Q782                  13174
# 2009       Q487704           Q782                   5509
# 2010       Q156213          Q1393                   3097
# 2011       Q156156          Q1393                   1278
# 2012       Q128137          Q1393                   2072
# 2013       Q390141           Q724                   1270
# 2014       Q506351           Q724                   6089
# 2015       Q497172           Q724                  10607
# 2016       Q502592           Q724                   5634
# 2017       Q506363           Q724                  10607
# 2018       Q507230           Q724                   1812
# 2019       Q507931           Q724                    853
# 2020       Q506326           Q724                   4518
# 2021       Q507216           Q724                    959
# 2022        Q58711           Q816                  21051
# 2023        Q58698           Q816                  14294
# 2024        Q58774           Q816                  16107
# 2025        Q58688           Q816                  23799
# 2026        Q58759           Q816                  11690
# 2027        Q58683           Q816                   4787
# 2028        Q58694           Q816                  25795
# 2029        Q58771           Q816                  29056
# 2030        Q54231           Q779                   2168
# 2031        Q54240           Q779                   1999
# 2032        Q54236           Q779                   1944
# 2033        Q54238           Q779                   1137
# 2034        Q54251           Q779                    nan
# 2035        Q54260          Q1387                    813
# 2036        Q54258          Q1387                   1458
# 2037        Q54254          Q1387                    487
#
#      population_for_FIPS_wikidata area_for_State_wikidata  \
# 0                            8290                  153909
# 1                           41183                  153909
# 2                           21232                  153909
# 3                           28495                  153909
# 4                           26984                  153909
# 5                          102945                  153909
# 6                           31364                  153909
# 7                           12842                  153909
# 8                           28057                  153909
# 9                           19599                  153909
# 10                          81508                  153909
# 11                          25683                  153909
# 12                          20676                  153909
# 13                          25446                  153909
# 14                           3045                  153909
# 15                          64135                  153909
# 16                          14009                  153909
# 17                          46275                  153909
# 18                          17959                  153909
# 19                          29584                  153909
# 20                         112916                  153909
# 21                          61044                  153909
# 22                          71453                  153909
# 23                          21221                  153909
# 24                          47999                  153909
# 25                           8464                  153909
# 26                           3102                  153909
# 27                         717190                  153909
# 28                          29071                  153909
# 29                          30918                  153909
# ...                           ...                     ...
# 2008                       196428                   28311
# 2009                       983429                   28311
# 2010                       206649                    6452
# 2011                       549684                    6452
# 2012                       169416                    6452
# 2013                       199431                   91646
# 2014                        54845                   91646
# 2015                       121164                   91646
# 2016                        57277                   91646
# 2017                        51706                   91646
# 2018                        34088                   91646
# 2019                        38940                   91646
# 2020                        30495                   91646
# 2021                        35013                   91646
# 2022                       215133                  295234
# 2023                       201201                  295234
# 2024                       129473                  295234
# 2025                       996554                  295234
# 2026                        20324                  295234
# 2027                         9049                  295234
# 2028                       107322                  295234
# 2029                        71934                  295234
# 2030                       939904                   14357
# 2031                       274150                   14357
# 2032                       898272                   14357
# 2033                       165562                   14357
# 2034                       117604                   14357
# 2035                        82397             3144.245565
# 2036                       126259             3144.245565
# 2037                       165035             3144.245565
#
#      elevation above sea level_for_State_wikidata  \
# 0                                             180
# 1                                             180
# 2                                             180
# 3                                             180
# 4                                             180
# 5                                             180
# 6                                             180
# 7                                             180
# 8                                             180
# 9                                             180
# 10                                            180
# 11                                            180
# 12                                            180
# 13                                            180
# 14                                            180
# 15                                            180
# 16                                            180
# 17                                            180
# 18                                            180
# 19                                            180
# 20                                            180
# 21                                            180
# 22                                            180
# 23                                            180
# 24                                            180
# 25                                            180
# 26                                            180
# 27                                            180
# 28                                            180
# 29                                            180
# ...                                           ...
# 2008                                          925
# 2009                                          925
# 2010                                           18
# 2011                                           18
# 2012                                           18
# 2013                                          180
# 2014                                          180
# 2015                                          180
# 2016                                          180
# 2017                                          180
# 2018                                          180
# 2019                                          180
# 2020                                          180
# 2021                                          180
# 2022                                         1250
# 2023                                         1250
# 2024                                         1250
# 2025                                         1250
# 2026                                         1250
# 2027                                         1250
# 2028                                         1250
# 2029                                         1250
# 2030                                          152
# 2031                                          152
# 2032                                          152
# 2033                                          152
# 2034                                          152
# 2035                                           60
# 2036                                           60
# 2037                                           60
#
#      inception_for_State_wikidata      motto text_for_State_wikidata  \
# 0            1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# 1            1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# 2            1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# 3            1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# 4            1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# 5            1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# 6            1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# 7            1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# 8            1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# 9            1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# 10           1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# 11           1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# 12           1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# 13           1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# 14           1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# 15           1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# 16           1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# 17           1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# 18           1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# 19           1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# 20           1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# 21           1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# 22           1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# 23           1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# 24           1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# 25           1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# 26           1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# 27           1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# 28           1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# 29           1788-01-02T00:00:00Z        Wisdom, Justice, Moderation
# ...                           ...                                ...
# 2008         1959-08-21T00:00:00Z  Ua Mau ke Ea o ka ʻĀina i ka Pono
# 2009         1959-08-21T00:00:00Z  Ua Mau ke Ea o ka ʻĀina i ka Pono
# 2010         1787-12-07T00:00:00Z           Liberty and Independence
# 2011         1787-12-07T00:00:00Z           Liberty and Independence
# 2012         1787-12-07T00:00:00Z           Liberty and Independence
# 2013         1820-03-15T00:00:00Z                             Dirigo
# 2014         1820-03-15T00:00:00Z                             Dirigo
# 2015         1820-03-15T00:00:00Z                             Dirigo
# 2016         1820-03-15T00:00:00Z                             Dirigo
# 2017         1820-03-15T00:00:00Z                             Dirigo
# 2018         1820-03-15T00:00:00Z                             Dirigo
# 2019         1820-03-15T00:00:00Z                             Dirigo
# 2020         1820-03-15T00:00:00Z                             Dirigo
# 2021         1820-03-15T00:00:00Z                             Dirigo
# 2022         1912-02-14T00:00:00Z                         Ditat Deus
# 2023         1912-02-14T00:00:00Z                         Ditat Deus
# 2024         1912-02-14T00:00:00Z                         Ditat Deus
# 2025         1912-02-14T00:00:00Z                         Ditat Deus
# 2026         1912-02-14T00:00:00Z                         Ditat Deus
# 2027         1912-02-14T00:00:00Z                         Ditat Deus
# 2028         1912-02-14T00:00:00Z                         Ditat Deus
# 2029         1912-02-14T00:00:00Z                         Ditat Deus
# 2030         1788-01-09T00:00:00Z            Qui transtulit sustinet
# 2031         1788-01-09T00:00:00Z            Qui transtulit sustinet
# 2032         1788-01-09T00:00:00Z            Qui transtulit sustinet
# 2033         1788-01-09T00:00:00Z            Qui transtulit sustinet
# 2034         1788-01-09T00:00:00Z            Qui transtulit sustinet
# 2035         1790-05-29T00:00:00Z                               Hope
# 2036         1790-05-29T00:00:00Z                               Hope
# 2037         1790-05-29T00:00:00Z                               Hope
#
#      native label_for_State_wikidata nickname_for_State_wikidata  \
# 0                   State of Georgia                         nan
# 1                   State of Georgia                         nan
# 2                   State of Georgia                         nan
# 3                   State of Georgia                         nan
# 4                   State of Georgia                         nan
# 5                   State of Georgia                         nan
# 6                   State of Georgia                         nan
# 7                   State of Georgia                         nan
# 8                   State of Georgia                         nan
# 9                   State of Georgia                         nan
# 10                  State of Georgia                         nan
# 11                  State of Georgia                         nan
# 12                  State of Georgia                         nan
# 13                  State of Georgia                         nan
# 14                  State of Georgia                         nan
# 15                  State of Georgia                         nan
# 16                  State of Georgia                         nan
# 17                  State of Georgia                         nan
# 18                  State of Georgia                         nan
# 19                  State of Georgia                         nan
# 20                  State of Georgia                         nan
# 21                  State of Georgia                         nan
# 22                  State of Georgia                         nan
# 23                  State of Georgia                         nan
# 24                  State of Georgia                         nan
# 25                  State of Georgia                         nan
# 26                  State of Georgia                         nan
# 27                  State of Georgia                         nan
# 28                  State of Georgia                         nan
# 29                  State of Georgia                         nan
# ...                              ...                         ...
# 2008                 State of Hawaii             The Aloha State
# 2009                 State of Hawaii             The Aloha State
# 2010               State of Delaware            The Small Wonder
# 2011               State of Delaware            The Small Wonder
# 2012               State of Delaware            The Small Wonder
# 2013                  State of Maine         The Pine Tree State
# 2014                  State of Maine         The Pine Tree State
# 2015                  State of Maine         The Pine Tree State
# 2016                  State of Maine         The Pine Tree State
# 2017                  State of Maine         The Pine Tree State
# 2018                  State of Maine         The Pine Tree State
# 2019                  State of Maine         The Pine Tree State
# 2020                  State of Maine         The Pine Tree State
# 2021                  State of Maine         The Pine Tree State
# 2022                State of Arizona      The Grand Canyon State
# 2023                State of Arizona      The Grand Canyon State
# 2024                State of Arizona      The Grand Canyon State
# 2025                State of Arizona      The Grand Canyon State
# 2026                State of Arizona      The Grand Canyon State
# 2027                State of Arizona      The Grand Canyon State
# 2028                State of Arizona      The Grand Canyon State
# 2029                State of Arizona      The Grand Canyon State
# 2030            State of Connecticut      The Constitution State
# 2031            State of Connecticut      The Constitution State
# 2032            State of Connecticut      The Constitution State
# 2033            State of Connecticut      The Constitution State
# 2034            State of Connecticut      The Constitution State
# 2035                    Rhode Island                         nan
# 2036                    Rhode Island                         nan
# 2037                    Rhode Island                         nan
#
#      population_for_State_wikidata short name_for_State_wikidata  \
# 0                         10214860                            GA
# 1                         10214860                            GA
# 2                         10214860                            GA
# 3                         10214860                            GA
# 4                         10214860                            GA
# 5                         10214860                            GA
# 6                         10214860                            GA
# 7                         10214860                            GA
# 8                         10214860                            GA
# 9                         10214860                            GA
# 10                        10214860                            GA
# 11                        10214860                            GA
# 12                        10214860                            GA
# 13                        10214860                            GA
# 14                        10214860                            GA
# 15                        10214860                            GA
# 16                        10214860                            GA
# 17                        10214860                            GA
# 18                        10214860                            GA
# 19                        10214860                            GA
# 20                        10214860                            GA
# 21                        10214860                            GA
# 22                        10214860                            GA
# 23                        10214860                            GA
# 24                        10214860                            GA
# 25                        10214860                            GA
# 26                        10214860                            GA
# 27                        10214860                            GA
# 28                        10214860                            GA
# 29                        10214860                            GA
# ...                            ...                           ...
# 2008                       1431603                            HI
# 2009                       1431603                            HI
# 2010                        945934                            DE
# 2011                        945934                            DE
# 2012                        945934                            DE
# 2013                       1328361                            ME
# 2014                       1328361                            ME
# 2015                       1328361                            ME
# 2016                       1328361                            ME
# 2017                       1328361                            ME
# 2018                       1328361                            ME
# 2019                       1328361                            ME
# 2020                       1328361                            ME
# 2021                       1328361                            ME
# 2022                       6828065                            AZ
# 2023                       6828065                            AZ
# 2024                       6828065                            AZ
# 2025                       6828065                            AZ
# 2026                       6828065                            AZ
# 2027                       6828065                            AZ
# 2028                       6828065                            AZ
# 2029                       6828065                            AZ
# 2030                       3590886                            CT
# 2031                       3590886                            CT
# 2032                       3590886                            CT
# 2033                       3590886                            CT
# 2034                       3590886                            CT
# 2035                       1056298                            RI
# 2036                       1056298                            RI
# 2037                       1056298                            RI
#
#      water as percent of area_for_State_wikidata
# 0                                           3.22
# 1                                           3.22
# 2                                           3.22
# 3                                           3.22
# 4                                           3.22
# 5                                           3.22
# 6                                           3.22
# 7                                           3.22
# 8                                           3.22
# 9                                           3.22
# 10                                          3.22
# 11                                          3.22
# 12                                          3.22
# 13                                          3.22
# 14                                          3.22
# 15                                          3.22
# 16                                          3.22
# 17                                          3.22
# 18                                          3.22
# 19                                          3.22
# 20                                          3.22
# 21                                          3.22
# 22                                          3.22
# 23                                          3.22
# 24                                          3.22
# 25                                          3.22
# 26                                          3.22
# 27                                          3.22
# 28                                          3.22
# 29                                          3.22
# ...                                          ...
# 2008                                       41.25
# 2009                                       41.25
# 2010                                       21.71
# 2011                                       21.71
# 2012                                       21.71
# 2013                                       12.82
# 2014                                       12.82
# 2015                                       12.82
# 2016                                       12.82
# 2017                                       12.82
# 2018                                       12.82
# 2019                                       12.82
# 2020                                       12.82
# 2021                                       12.82
# 2022                                        0.35
# 2023                                        0.35
# 2024                                        0.35
# 2025                                        0.35
# 2026                                        0.35
# 2027                                        0.35
# 2028                                        0.35
# 2029                                        0.35
# 2030                                       12.65
# 2031                                       12.65
# 2032                                       12.65
# 2033                                       12.65
# 2034                                       12.65
# 2035                                       33.08
# 2036                                       33.08
# 2037                                       33.08
#
# [2038 rows x 19 columns]

# %%
"""
After first time search, now we have more columns(including the Q nodes), we can search again to get more results
Also, because this time we already have Q nodes in supplied data, we will skip wikidata part's search
"""
search_res2 = a.search_with_data(query=None, supplied_data=aug2)
# Out:
# [INFO] Q nodes columns found in input data, will not run wikifier.

# %%
# run get next page twice
s3 = search_res2.get_next_page()
s4 = search_res2.get_next_page()
# Out:
# Wikidata Q nodes inputs detected! Will search with it.
# Totally 2 Q nodes columns detected!

# %%
# show the search results details
# wikidata has no dynamic score
output_df = pd.DataFrame()
for each in s3:
    col1 = each.display()
    output_df = output_df.append(col1)
output_df = output_df.reset_index()
output_df
# Out:
#     index                                              title  \
# 0       0           wikidata search result for FIPS_wikidata
# 1       0          wikidata search result for State_wikidata
# 2       0                                   Unemployment.csv
# 3       0                                        educate.csv
# 4       0                                        poverty.csv
# 5       0                                     population.csv
# 6       0  List_of_United_States_counties_by_per_capita_i...
# 7       0                                        poverty.csv
# 8       0                                   Unemployment.csv
# 9       0                                        educate.csv
# 10      0                                     population.csv
# 11      0         Most-Recent-Cohorts-Scorecard-Elements.csv
# 12      0         Most-Recent-Cohorts-Scorecard-Elements.csv
# 13      0  2017%E2%80%9318_New_Orleans_Privateers_women%2...
# 14      0  List_of_United_States_counties_by_per_capita_i...
# 15      0  List_of_United_States_counties_by_per_capita_i...
# 16      0                                   Unemployment.csv
# 17      0                                        poverty.csv
# 18      0                                     population.csv
# 19      0                                        educate.csv
#
#                                               columns  \
# 0                         population, area, inception
# 1   population, nickname, motto text, demonym, nat...
# 2   FIPStxt State Area_name Rural_urban_continuum_...
# 3   FIPS Code State Area name 2003 Rural-urban Con...
# 4   FIPStxt State Area_Name Rural-urban_Continuum_...
# 5   FIPS State Area_Name Rural-urban_Continuum Cod...
# 6   Rank County-area State Per capita income Media...
# 7   FIPStxt State Area_Name Rural-urban_Continuum_...
# 8   FIPStxt State Area_name Rural_urban_continuum_...
# 9   FIPS Code State Area name 2003 Rural-urban Con...
# 10  FIPS State Area_Name Rural-urban_Continuum Cod...
# 11  UNITID OPEID OPEID6 INSTNM CITY STABBR INSTURL...
# 12  UNITID OPEID OPEID6 INSTNM CITY STABBR INSTURL...
# 13  Date time, TV·November 10, 2017 * 7:00 pm Rank...
# 14  Rank County-area State Per capita income Media...
# 15  Rank County-area State Per capita income Media...
# 16  FIPStxt State Area_name Rural_urban_continuum_...
# 17  FIPStxt State Area_Name Rural-urban_Continuum_...
# 18  FIPS State Area_Name Rural-urban_Continuum Cod...
# 19  FIPS Code State Area name 2003 Rural-urban Con...
#
#                                          join columns     score
# 0                                       FIPS_wikidata  1.000000
# 1                                      State_wikidata  1.000000
# 2                                    FIPStxt_wikidata  0.220971
# 3                                  FIPS Code_wikidata  0.220971
# 4                                    FIPStxt_wikidata  0.220971
# 5                                       FIPS_wikidata  0.220971
# 6                                      State_wikidata  0.331456
# 7                                      State_wikidata  0.883883
# 8                                      State_wikidata  0.883883
# 9                                      State_wikidata  0.883883
# 10                                     State_wikidata  0.883883
# 11                                    STABBR_wikidata  0.883883
# 12                                             NPCURL  0.002387
# 13  Opponent #·at Louisiana  Preseason WNIT First ...  0.008486
# 14                                              State  0.008486
# 15                                        County-area  0.021214
# 16                                          Area_name  0.022540
# 17                                          Area_Name  0.022540
# 18                                          Area_Name  0.023866
# 19                                          Area name  0.025191

# %%
# run download function one search result
download_res = s3[4].download(supplied_data=search_res.supplied_data)
# Out:
# Current column: FIPStxt
# The best matching P node is P882
# Current column: State
# The best matching P node is P5086
# Current column: Area_Name
# The best matching P node is P2390
# [WARNING] Coverage of Q nodes is 0.012210394489668128 which is less than threshold 0.7
# Current column: Rural-urban_Continuum_Code_2003
# A columns with all numerical values and useless detected, skipped
# Current column: Urban_Influence_Code_2003
# A columns with all numerical values and useless detected, skipped
# Current column: Rural-urban_Continuum_Code_2013
# A columns with all numerical values and useless detected, skipped
# Current column: Urban_Influence_Code_2013
# A columns with all numerical values and useless detected, skipped
# Current column: POVALL_2017
# [WARNING] Coverage of data is 0.1593613024420789 which is less than threshold 0.7
# Current column: CI90LBAll_2017
# [WARNING] Coverage of data is 0.2016280525986224 which is less than threshold 0.7
# Current column: CI90UBALL_2017
# [WARNING] Coverage of data is 0.12867877269881026 which is less than threshold 0.7
# Current column: PCTPOVALL_2017
# A columns with all numerical values and useless detected, skipped
# Current column: CI90LBALLP_2017
# A columns with all numerical values and useless detected, skipped
# Current column: CI90UBALLP_2017
# A columns with all numerical values and useless detected, skipped
# Current column: POV017_2017
# A columns with all numerical values and useless detected, skipped
# Current column: CI90LB017_2017
# A columns with all numerical values and useless detected, skipped
# Current column: CI90UB017_2017
# [WARNING] Coverage of data is 0.365372573575454 which is less than threshold 0.7
# Current column: PCTPOV017_2017
# A columns with all numerical values and useless detected, skipped
# Current column: CI90LB017P_2017
# A columns with all numerical values and useless detected, skipped
# Current column: CI90UB017P_2017
# A columns with all numerical values and useless detected, skipped
# Current column: POV517_2017
# A columns with all numerical values and useless detected, skipped
# Current column: CI90LB517_2017
# A columns with all numerical values and useless detected, skipped
# Current column: CI90UB517_2017
# A columns with all numerical values and useless detected, skipped
# Current column: PCTPOV517_2017
# A columns with all numerical values and useless detected, skipped
# Current column: CI90LB517P_2017
# A columns with all numerical values and useless detected, skipped
# Current column: CI90UB517P_2017
# A columns with all numerical values and useless detected, skipped
# Current column: MEDHHINC_2017
# [ERROR] No candidate P nodes found for input column : [MEDHHINC_2017]
# Current column: CI90LBINC_2017
# [ERROR] No candidate P nodes found for input column : [CI90LBINC_2017]
# Current column: CI90UBINC_2017
# [ERROR] No candidate P nodes found for input column : [CI90UBINC_2017]
# Current column: POV04_2017
# [WARNING] Coverage of data is 0.01628052598622417 which is less than threshold 0.7
# Current column: CI90LB04_2017
# [WARNING] Coverage of data is 0.01628052598622417 which is less than threshold 0.7
# Current column: CI90UB04_2017
# [WARNING] Coverage of data is 0.01628052598622417 which is less than threshold 0.7
# Current column: PCTPOV04_2017
# [WARNING] Coverage of data is 0.01628052598622417 which is less than threshold 0.7
# Current column: CI90LB04P_2017
# [WARNING] Coverage of data is 0.01628052598622417 which is less than threshold 0.7
# Current column: CI90UB04P_2017
# [WARNING] Coverage of data is 0.01628052598622417 which is less than threshold 0.7
#  - start getting pairs for ([6], [34])

# %%
# run augment function on one search result
aug_res = s3[3].augment(supplied_data=search_res.supplied_data)
# Out:
# Current column: FIPS Code
# The best matching P node is P882
# Current column: State
# The best matching P node is P5086
# Current column: Area name
# The best matching P node is P2390
# [WARNING] Coverage of Q nodes is 0.011574779165397502 which is less than threshold 0.7
# Current column: 2003 Rural-urban Continuum Code
# A columns with all numerical values and useless detected, skipped
# Current column: 2003 Urban Influence Code
# A columns with all numerical values and useless detected, skipped
# Current column: 2013 Rural-urban Continuum Code
# A columns with all numerical values and useless detected, skipped
# Current column: 2013 Urban Influence Code
# A columns with all numerical values and useless detected, skipped
# Current column: Less than a high school diploma, 1970
# The best matching P node is P3060
# [WARNING] Coverage of Q nodes is 0.558939993908011 which is less than threshold 0.7
# Current column: High school diploma only, 1970
# The best matching P node is P3060
# [WARNING] Coverage of Q nodes is 0.5717331708802924 which is less than threshold 0.7
# Current column: Some college (1-3 years), 1970
# The best matching P node is P3060
# [WARNING] Coverage of Q nodes is 0.6067621078282059 which is less than threshold 0.7
# Current column: Four years of college or higher, 1970
# The best matching P node is P3060
# [WARNING] Coverage of Q nodes is 0.5954919281145294 which is less than threshold 0.7
# Current column: Percent of adults with less than a high school diploma, 1970
# A columns with all numerical values and useless detected, skipped
# Current column: Percent of adults with a high school diploma only, 1970
# A columns with all numerical values and useless detected, skipped
# Current column: Percent of adults completing some college (1-3 years), 1970
# A columns with all numerical values and useless detected, skipped
# Current column: Percent of adults completing four years of college or higher, 1970
# A columns with all numerical values and useless detected, skipped
# Current column: Less than a high school diploma, 1980
# The best matching P node is P3060
# [WARNING] Coverage of Q nodes is 0.5875723423697837 which is less than threshold 0.7
# Current column: High school diploma only, 1980
# The best matching P node is P3060
# [WARNING] Coverage of Q nodes is 0.582394151690527 which is less than threshold 0.7
# Current column: Some college (1-3 years), 1980
# The best matching P node is P3060
# [WARNING] Coverage of Q nodes is 0.6070667072799268 which is less than threshold 0.7
# Current column: Four years of college or higher, 1980
# The best matching P node is P3060
# [WARNING] Coverage of Q nodes is 0.5927505330490405 which is less than threshold 0.7
# Current column: Percent of adults with less than a high school diploma, 1980
# A columns with all numerical values and useless detected, skipped
# Current column: Percent of adults with a high school diploma only, 1980
# A columns with all numerical values and useless detected, skipped
# Current column: Percent of adults completing some college (1-3 years), 1980
# A columns with all numerical values and useless detected, skipped
# Current column: Percent of adults completing four years of college or higher, 1980
# A columns with all numerical values and useless detected, skipped
# Current column: Less than a high school diploma, 1990
# The best matching P node is P3060
# [WARNING] Coverage of Q nodes is 0.5866585440146208 which is less than threshold 0.7
# Current column: High school diploma only, 1990
# The best matching P node is P3060
# [WARNING] Coverage of Q nodes is 0.558330795004569 which is less than threshold 0.7
# Current column: Some college or associate's degree, 1990
# The best matching P node is P3060
# [WARNING] Coverage of Q nodes is 0.5784343588181541 which is less than threshold 0.7
# Current column: Bachelor's degree or higher, 1990
# The best matching P node is P3060
# [WARNING] Coverage of Q nodes is 0.5945781297593664 which is less than threshold 0.7
# Current column: Percent of adults with less than a high school diploma, 1990
# A columns with all numerical values and useless detected, skipped
# Current column: Percent of adults with a high school diploma only, 1990
# A columns with all numerical values and useless detected, skipped
# Current column: Percent of adults completing some college or associate's degree, 1990
# A columns with all numerical values and useless detected, skipped
# Current column: Percent of adults with a bachelor's degree or higher, 1990
# A columns with all numerical values and useless detected, skipped
# Current column: Less than a high school diploma, 2000
# The best matching P node is P3060
# [WARNING] Coverage of Q nodes is 0.5857447456594578 which is less than threshold 0.7
# Current column: High school diploma only, 2000
# The best matching P node is P3060
# [WARNING] Coverage of Q nodes is 0.5702101736216875 which is less than threshold 0.7
# Current column: Some college or associate's degree, 2000
# The best matching P node is P3060
# [WARNING] Coverage of Q nodes is 0.5641181845872677 which is less than threshold 0.7
# Current column: Bachelor's degree or higher, 2000
# The best matching P node is P3060
# [WARNING] Coverage of Q nodes is 0.5726469692354553 which is less than threshold 0.7
# Current column: Percent of adults with less than a high school diploma, 2000
# A columns with all numerical values and useless detected, skipped
# Current column: Percent of adults with a high school diploma only, 2000
# A columns with all numerical values and useless detected, skipped
# Current column: Percent of adults completing some college or associate's degree, 2000
# A columns with all numerical values and useless detected, skipped
# Current column: Percent of adults with a bachelor's degree or higher, 2000
# A columns with all numerical values and useless detected, skipped
# Current column: Less than a high school diploma, 2013-17
# The best matching P node is P3060
# [WARNING] Coverage of Q nodes is 0.6140724946695096 which is less than threshold 0.7
# Current column: High school diploma only, 2013-17
# The best matching P node is P3060
# [WARNING] Coverage of Q nodes is 0.5513250076149863 which is less than threshold 0.7
# Current column: Some college or associate's degree, 2013-17
# The best matching P node is P3060
# [WARNING] Coverage of Q nodes is 0.536399634480658 which is less than threshold 0.7
# Current column: Bachelor's degree or higher, 2013-17
# The best matching P node is P3060
# [WARNING] Coverage of Q nodes is 0.5613767895217788 which is less than threshold 0.7
# Current column: Percent of adults with less than a high school diploma, 2013-17
# A columns with all numerical values and useless detected, skipped
# Current column: Percent of adults with a high school diploma only, 2013-17
# A columns with all numerical values and useless detected, skipped
# Current column: Percent of adults completing some college or associate's degree, 2013-17
# A columns with all numerical values and useless detected, skipped
# Current column: Percent of adults with a bachelor's degree or higher, 2013-17
# A columns with all numerical values and useless detected, skipped
#  - start getting pairs for ([6], [47])

# %%
download_res['augmentData'].head()
# Out:
#    FIPStxt State       Area_Name  Rural-urban_Continuum_Code_2003  \
# 0        0    US   United States                              NaN
# 1     1000    AL         Alabama                              NaN
# 2     1001    AL  Autauga County                              2.0
# 3     1003    AL  Baldwin County                              4.0
# 4     1005    AL  Barbour County                              6.0
#
#    Urban_Influence_Code_2003  Rural-urban_Continuum_Code_2013  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        2.0                              2.0
# 3                        5.0                              3.0
# 4                        6.0                              6.0
#
#    Urban_Influence_Code_2013  POVALL_2017  CI90LBAll_2017  CI90UBALL_2017  \
# 0                        NaN          NaN             NaN             NaN
# 1                        NaN          NaN             NaN             NaN
# 2                        2.0          NaN             NaN             NaN
# 3                        2.0          NaN             NaN             NaN
# 4                        6.0          NaN             NaN             NaN
#
#        ...        CI90UBINC_2017  POV04_2017  CI90LB04_2017  CI90UB04_2017  \
# 0      ...                60,422   3,932,969      3,880,645      3,985,293
# 1      ...                48,935      78,986         75,009         82,963
# 2      ...                64,565         NaN            NaN            NaN
# 3      ...                60,775         NaN            NaN            NaN
# 4      ...                35,762         NaN            NaN            NaN
#
#    PCTPOV04_2017  CI90LB04P_2017  CI90UB04P_2017  FIPStxt_wikidata  \
# 0           20.2            19.9            20.5
# 1           27.7            26.3            29.1
# 2            NaN             NaN             NaN           Q156168
# 3            NaN             NaN             NaN           Q156163
# 4            NaN             NaN             NaN           Q109437
#
#    State_wikidata  joining_pairs
# 0                             []
# 1            Q173             []
# 2            Q173             []
# 3            Q173         [1898]
# 4            Q173         [1107]
#
# [5 rows x 37 columns]

# %%
aug_res['augmentData'].head()
# Out:
#   d3mIndex   FIPS State              Area RUCCode POVALL_2016 FIPS_wikidata  \
# 0        1  13297    GA     Walton County       1       11385       Q498312
# 1        2  13137    GA  Habersham County       6        6500       Q501096
# 2        3  54017    WV  Doddridge County       9        1460       Q494081
# 3        4  55055    WI  Jefferson County       4        7618       Q500958
# 4        5  38065    ND     Oliver County       8         191        Q48933
#
#   State_wikidata 2003 Rural-urban Continuum Code 2003 Urban Influence Code  \
# 0          Q1428                             1.0                       1.0
# 1          Q1428                             6.0                       5.0
# 2          Q1371                             9.0                       8.0
# 3          Q1537                             4.0                       3.0
# 4          Q1207                             8.0                       7.0
#
#                       ...                      \
# 0                     ...
# 1                     ...
# 2                     ...
# 3                     ...
# 4                     ...
#
#   Percent of adults with less than a high school diploma, 1970  \
# 0                                               74.7
# 1                                               67.7
# 2                                               69.6
# 3                                               48.0
# 4                                               71.6
#
#   Percent of adults with less than a high school diploma, 1980  \
# 0                                               62.0
# 1                                               56.5
# 2                                               48.2
# 3                                               32.3
# 4                                               45.6
#
#   Percent of adults with less than a high school diploma, 1990  \
# 0                                               42.1
# 1                                               41.0
# 2                                               35.4
# 3                                               23.0
# 4                                               31.8
#
#   Percent of adults with less than a high school diploma, 2000  \
# 0                                               26.5
# 1                                               29.1
# 2                                               30.6
# 3                                               15.3
# 4                                               20.1
#
#   Percent of adults with less than a high school diploma, 2013-17  \
# 0                                               13.2
# 1                                               22.0
# 2                                               19.8
# 3                                                8.6
# 4                                               11.3
#
#   Some college (1-3 years), 1970 Some college (1-3 years), 1980  \
# 0                          493.0                         1238.0
# 1                          733.0                         1354.0
# 2                          143.0                          331.0
# 3                         2996.0                         4961.0
# 4                           88.0                          234.0
#
#   Some college or associate's degree, 1990  \
# 0                                   4028.0
# 1                                   2958.0
# 2                                    659.0
# 3                                   9318.0
# 4                                    357.0
#
#   Some college or associate's degree, 2000  \
# 0                                   9564.0
# 1                                   5006.0
# 2                                    878.0
# 3                                  14135.0
# 4                                    457.0
#
#   Some college or associate's degree, 2013-17
# 0                                     17334.0
# 1                                      7621.0
# 2                                      1385.0
# 3                                     19174.0
# 4                                       550.0
#
# [5 rows x 55 columns]

# %%
import pickle
temp = pickle.dumps(s3[4])
# this one is used for primitive
temp
# Out:
# b'\x80\x03cdatamart_isi.entries\nDatamartSearchResult\nq\x00)\x81q\x01}q\x02(X\r\x00\x00\x00search_resultq\x03}q\x04(X\x05\x00\x00\x00scoreq\x05}q\x06(X\x08\x00\x00\x00datatypeq\x07X\'\x00\x00\x00http://www.w3.org/2001/XMLSchema#doubleq\x08X\x04\x00\x00\x00typeq\tX\x07\x00\x00\x00literalq\nX\x05\x00\x00\x00valueq\x0bX\x13\x00\x00\x000.22097086912079575q\x0cuX\x04\x00\x00\x00rankq\r}q\x0e(h\x07X$\x00\x00\x00http://www.w3.org/2001/XMLSchema#intq\x0fh\tX\x07\x00\x00\x00literalq\x10h\x0bX\x01\x00\x00\x002q\x11uX\x08\x00\x00\x00variableq\x12}q\x13(h\tX\x03\x00\x00\x00uriq\x14h\x0bXV\x00\x00\x00http://www.wikidata.org/entity/statement/D1000006-d547afad-3309-46b4-990d-946df3efbabdq\x15uX\x07\x00\x00\x00datasetq\x16}q\x17(h\tX\x03\x00\x00\x00uriq\x18h\x0bX\'\x00\x00\x00http://www.wikidata.org/entity/D1000006q\x19uX\x03\x00\x00\x00urlq\x1a}q\x1b(h\tX\x03\x00\x00\x00uriq\x1ch\x0bXa\x00\x00\x00https://raw.githubusercontent.com/usc-isi-i2/datamart-userend/master/example_datasets/poverty.csvq\x1duX\x05\x00\x00\x00titleq\x1e}q\x1f(X\x08\x00\x00\x00xml:langq X\x02\x00\x00\x00enq!h\tX\x07\x00\x00\x00literalq"h\x0bX\x0b\x00\x00\x00poverty.csvq#uX\x08\x00\x00\x00keywordsq$}q%(h\x07X\'\x00\x00\x00http://www.w3.org/2001/XMLSchema#stringq&h\tX\x07\x00\x00\x00literalq\'h\x0bX5\x02\x00\x00FIPStxt State Area_Name Rural-urban_Continuum_Code_2003 Urban_Influence_Code_2003 Rural-urban_Continuum_Code_2013 Urban_Influence_Code_2013 POVALL_2017 CI90LBAll_2017 CI90UBALL_2017 PCTPOVALL_2017 CI90LBALLP_2017 CI90UBALLP_2017 POV017_2017 CI90LB017_2017 CI90UB017_2017 PCTPOV017_2017 CI90LB017P_2017 CI90UB017P_2017 POV517_2017 CI90LB517_2017 CI90UB517_2017 PCTPOV517_2017 CI90LB517P_2017 CI90UB517P_2017 MEDHHINC_2017 CI90LBINC_2017 CI90UBINC_2017 POV04_2017 CI90LB04_2017 CI90UB04_2017 PCTPOV04_2017 CI90LB04P_2017 CI90UB04P_2017 FIPStxt_wikidata State_wikidataq(uX\x11\x00\x00\x00extra_informationq)}q*(h\x07X\'\x00\x00\x00http://www.w3.org/2001/XMLSchema#stringq+h\tX\x07\x00\x00\x00literalq,h\x0bX\x02\x00\x00\x00{}q-uX\x0c\x00\x00\x00datasetLabelq.}q/(h X\x02\x00\x00\x00enq0h\tX\x07\x00\x00\x00literalq1h\x0bX\x08\x00\x00\x00D1000006q2uX\x0c\x00\x00\x00variableNameq3}q4(h\x07X\'\x00\x00\x00http://www.w3.org/2001/XMLSchema#stringq5h\tX\x07\x00\x00\x00literalq6h\x0bX\x10\x00\x00\x00FIPStxt_wikidataq7uuX\n\x00\x00\x00query_jsonq8}q9(X\x08\x00\x00\x00keywordsq:]q;X\t\x00\x00\x00variablesq<}q=X\r\x00\x00\x00FIPS_wikidataq>X+\x06\x00\x00Q489847 Q496971 Q502587 Q26716 Q508220 Q26699 Q374765 Q61352 Q63719 Q54251 Q488847 Q512832 Q389365 Q488917 Q485922 Q1125008 Q507870 Q491035 Q26880 Q500674 Q501345 Q498024 Q484620 Q494536 Q504350 Q484570 Q109270 Q431440 Q485582 Q504284 Q495570 Q109631 Q54076 Q502240 Q58771 Q490378 Q26697 Q509786 Q503366 Q502373 Q119372 Q485984 Q506676 Q489743 Q504850 Q376053 Q500663 Q110528 Q61036 Q495154 Q487243 Q507099 Q500880 Q502442 Q506225 Q137509 Q501785 Q496406 Q26587 Q513933 Q112807 Q502200 Q108503 Q486535 Q495096 Q490649 Q496771 Q500891 Q484991 Q404898 Q943772 Q500813 Q495340 Q156191 Q28321 Q591156 Q340591 Q374358 Q486765 Q26614 Q494771 Q486067 Q486248 Q342803 Q312475 Q497795 Q109457 Q495393 Q306343 Q492310 Q113185 Q483990 Q109293 Q494241 Q485571 Q376764 Q48933 Q302165 Q49259 Q505644 Q490088 Q488175 Q494480 Q484420 Q510947 Q504428 Q496664 Q502929 Q110983 Q506351 Q501568 Q507078 Q489668 Q484668 Q490014 Q504838 Q497284 Q484367 Q115583 Q486011 Q156374 Q185533 Q506752 Q477870 Q486348 Q177678 Q505886 Q114923 Q374527 Q112149 Q374200 Q494716 Q490161 Q492488 Q486495 Q493709 Q490414 Q156377 Q501323 Q497377 Q491850 Q491436 Q338424 Q109503 Q61018 Q112456 Q490989 Q494990 Q504445 Q489620 Q485808 Q488826 Q507907 Q503468 Q503554 Q54258 Q335121 Q493255 Q167565 Q48937 Q130006 Q500854 Q586070 Q486288 Q485804 Q493957 Q484404 Q26895 Q489894 Q374382 Q27051 Q486087 Q503461 Q490494 Q495175 Q112603 Q112915 Q494514 Q115061 Q509910 Q461562 Q491514 Q280820 Q502739 Q500861 Q491170 Q204761 Q488805 Q111584 Q493074 Q496139 Q486112 Q511713 Q490002 Q502278 Q485577 Q500569 Q341708 Q4 ...

# %%
s3[3].search_type
# Out:
# 'general'
